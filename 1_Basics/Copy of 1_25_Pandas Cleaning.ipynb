# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_25_Pandas Cleaning.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !pip install datasets

# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
# Out:
# ...
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Sort by Salary (1.25.1)

# %%
df.sort_values(by='salary_year_avg', ascending=False, inplace=True)         # "ascending = False" to descending order

# %%
df.iloc[0:10]
# Out:
#          job_title_short  ...                                    job_type_skills
# 665729     Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'libraries': ['ha...
# 380187  Business Analyst  ...                                               None
# 130855     Data Engineer  ...  {'libraries': ['react', 'flutter', 'airflow'],...
# 535260     Data Engineer  ...  {'analyst_tools': ['sas', 'ssis', 'tableau'], ...
# 213687     Data Engineer  ...  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 252564      Data Analyst  ...                                               None
# 260702     Data Engineer  ...       {'other': ['flow'], 'programming': ['java']}
# 248548     Data Engineer  ...  {'analyst_tools': ['excel'], 'cloud': ['aws'],...
# 704118      Data Analyst  ...                                               None
# 365886      Data Analyst  ...                                               None
#
# [10 rows x 17 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Create Remote Column (1.25.2)

# %%
df['is_remote'] = df.job_work_from_home == True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 554784 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df
# Out:
#               job_title_short  ... is_remote
# 554784         Data Scientist  ...     False
# 665811  Senior Data Scientist  ...     False
# 168402           Data Analyst  ...      True
# 387378         Data Scientist  ...     False
# 160521         Data Scientist  ...      True
# ...                       ...  ...       ...
# 785736      Software Engineer  ...     False
# 785737           Data Analyst  ...     False
# 785738       Business Analyst  ...     False
# 785739          Data Engineer  ...     False
# 785740      Software Engineer  ...     False
#
# [785741 rows x 18 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Extract Year from Date (1.25.3)

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])            # first convert 'job_posted_date' to a pandas datetime with pd.to_datetime

df['job_posted_year'] = df.job_posted_date.dt.year                      # assing new column 'job_posted_year' to converted value from 'job_posted_date' using .dt.year

df.head(5)
# Out:
#               job_title_short  ... job_posted_year
# 554784         Data Scientist  ...            2023
# 665811  Senior Data Scientist  ...            2023
# 168402           Data Analyst  ...            2023
# 387378         Data Scientist  ...            2023
# 160521         Data Scientist  ...            2023
#
# [5 rows x 19 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Drop Missing Salaries (1.25.4)

# %%
df.dropna(subset=['salary_year_avg'], inplace=True)

df.head(5)
# Out:
#               job_title_short  ... job_posted_year
# 554784         Data Scientist  ...            2023
# 665811  Senior Data Scientist  ...            2023
# 168402           Data Analyst  ...            2023
# 387378         Data Scientist  ...            2023
# 160521         Data Scientist  ...            2023
#
# [5 rows x 19 columns]

# %% [markdown]
# ---
