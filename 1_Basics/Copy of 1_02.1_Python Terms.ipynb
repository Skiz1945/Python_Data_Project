# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_02.1_Python Terms.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Example of Object (1.2.1.1)

# %%
1
type(1)
# Out:
# int

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Define Variable (1.2.1.2)

# %%
name = 'Nadja'
print(name)
# Out:
# Nadja

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Define Function (1.2.1.3)

# %%
def greet():
  return ('Hej Malac, voljim te')

print(greet())
# Out:
# Hej Malac, voljim te

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Define Class (1.2.1.4)

# %%
job_title = "Data Analyst"
job_location = "United States"
job_salary = 90000

class JobPost:
    def __init__(self, title, location, salary):
        self.title = title                            #atributes
        self.location = location                      #atributes
        self.salary = salary                          #atributes
    def display_info(self):
        return print(f"JOB:       {self.title}\nLOCATION:  {self.location}\nSALARY:    ${self.salary:,.0f}")   #method  (function in class)

JobPost(job_title, job_location, job_salary)

# %%
job_1 = JobPost(job_title, job_location, job_salary)

print(job_1.title)
print(job_1.location)
print(job_1.salary)
# Out:
# Data Analyst
# United States
# 90000

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Call Method (1.2.1.5)

# %%
job_1.display_info()
# Out:
# JOB:       Data Analyst
# LOCATION:  United States
# SALARY:    $90,000

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Example of Attribute (1.2.1.6)

# %%
job_1 = JobPost(job_title, job_location, job_salary)

print(job_1.title)
print(job_1.location)
print(job_1.salary)
# Out:
# Data Analyst
# United States
# 90000

# %% [markdown]
# ---
