# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_13_Loops.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Print Job Titles (1.13.1)

# %%
# Code Needed
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

for job_title in job_titles:
  print(job_title)
# Out:
# Data Scientist
# Data Analyst
# Machine Learning Engineer

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Total Job Postings (1.13.2)

# %%
# Code Needed
job_postings = [5, 10, 15, 20, 25]

total_postings = 0
index = 0
while index < len(job_postings):
  total_postings += job_postings[index]
  index += 1
print(total_postings)
# Out:
# 75

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Print Job Titles with Index (1.13.3)

# %%
# Code Needed
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']          # importan,  -enumerate()- to see both, index and title

for index, title in enumerate(job_titles):
  print(f'{index}: {title}')
# Out:
# 0: Data Scientist
# 1: Data Analyst
# 2: Machine Learning Engineer

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Find First Engineer (1.13.4)

# %%
# Code Needed
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Software Engineer']

index = 0
while index < len(job_titles):
  if 'Engineer' in job_titles[index]:
    print(job_titles[index])
    break
  index += 1
# Out:
# Machine Learning Engineer

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Print Job Titles Containing 'Data' (1.13.5)

# %%
# Code Needed
positions_skills = {                                                    # nested -for- loop
    'Data Scientist': ['Python', 'R'],
    'Data Analyst': ['SQL', 'Excel'],
    'Machine Learning Engineer': ['Python', 'TensorFlow']
}

for position, skills in positions_skills.items():
  for skill in skills:
    print(f'The role of {position} requires proficienncy in {skill}.')
# Out:
# The role of Data Scientist requires proficienncy in Python.
# The role of Data Scientist requires proficienncy in R.
# The role of Data Analyst requires proficienncy in SQL.
# The role of Data Analyst requires proficienncy in Excel.
# The role of Machine Learning Engineer requires proficienncy in Python.
# The role of Machine Learning Engineer requires proficienncy in TensorFlow.

# %% [markdown]
# ---
