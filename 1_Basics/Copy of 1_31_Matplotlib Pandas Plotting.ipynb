# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_31_Matplotlib Pandas Plotting.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !pip install datasets

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %% [markdown]
# ## 🟩 Job Posting Location Bar Plot (1.31.1)

# %%
job_posting_location = df['job_via'].value_counts().head(5)

# %%
job_posting_location.plot(kind='bar')
# Out:
# <Axes: xlabel='job_via'>

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Job Postings Trend Line Plot (1.31.2)

# %%
df['monthly_job_counts'] = df['job_posted_date'].dt.to_period('M')

# %%
job_posting_trend = df['monthly_job_counts'].value_counts().sort_index()

# %%
job_posting_trend
# Out:
# monthly_job_counts
# 2023-01    91822
# 2023-02    64578
# 2023-03    64084
# 2023-04    62919
# 2023-05    52104
# 2023-06    61572
# 2023-07    63777
# 2023-08    75162
# 2023-09    62359
# 2023-10    66611
# 2023-11    64450
# 2023-12    56303
# Freq: M, Name: count, dtype: int64

# %%
job_posting_trend.plot(kind='line')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
plt.title('Trend of Job Postings Over Time')
# Out:
# Text(0.5, 1.0, 'Trend of Job Postings Over Time')

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Top Job Locations (1.31.3)

# %%
job_locations = df['job_location'].value_counts().head(5)

# %%
job_locations = job_locations.sort_values(ascending=True)

# %%
job_locations
# Out:
# job_location
# London, UK                     10564
# Bengaluru, Karnataka, India    11474
# Paris, France                  12311
# Singapore                      23415
# Anywhere                       69552
# Name: count, dtype: int64

# %%
job_locations.plot(x='job_locations', y='counts', kind='barh')
plt.xlabel('Count of Jobs')
plt.ylabel('Job Location')
plt.title('Number of Job Postings by Job Locations')
# Out:
# Text(0.5, 1.0, 'Number of Job Postings by Job Locations')

# %% [markdown]
# ---
