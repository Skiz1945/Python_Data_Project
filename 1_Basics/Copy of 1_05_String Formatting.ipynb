# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_05_String Formatting.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Concatenate Strings (1.5.1)

# %%
# Code Needed
job_title = 'Data Scientist'

new_job_title = 'Job Title: ' + job_title
print(new_job_title)
# Out:
# Job Title: Data Scientist

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Format with f-strings (1.5.2)

# %%
# Code Needed
position = 'Data Scientist'
company = 'DataWiz Inc.'

result = f'{position} at {company}'                     # best way to formatting
print(result)
# Out:
# Data Scientist at DataWiz Inc.

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Format with str.format() (1.5.3)

# %%
# Code Needed
role = 'Data Analyst'
skill = 'Python'

result_1 = 'Role: {}, Skill: {}'.format(role, skill)
print(result_1)
# Out:
# Role: Data Analyst, Skill: Python

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Format with %-formatting (1.5.4)

# %%
# Code Needed
role = 'Data Engineer'
skill = 'SQL'

result_2 = 'Role: %s; Skill: %s' % (role, skill)
print(result_2)
# Out:
# Role: Data Engineer; Skill: SQL

# %% [markdown]
# ---
